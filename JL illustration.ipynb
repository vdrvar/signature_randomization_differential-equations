# %% [markdown]
# # Illustration of the JL Lemma

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import math

# %%
A = np.random.normal(0, 1, size=(3, 2, 4))
v = np.random.normal(0, 1, size=(3))
A, v
# Out:
# (array([[[ 0.09732031, -0.46303145, -0.59047379, -1.31950785],
#          [ 0.89280359,  0.66652322, -1.07864246,  0.11477798]],
#
#         [[-0.11227256, -0.17621382,  1.83374507,  1.89353748],
#          [ 1.32639985,  0.86849096,  0.00545442, -0.92839753]],
#
#         [[ 3.25753306, -0.32783303,  1.15316959,  0.4893164 ],
#          [ 0.90353066, -0.65429969, -1.54616799, -0.16970298]]]),
#  array([0.48203264, 0.81904521, 0.30004419]))

# %% [markdown]
# #### Let n=3, let us simulate 3 clusters of 10 point each distributed according to some Gaussians

# %%
mean_1 = [5, 0, 0]
cov_1 = [[1/10, 0, 0], [0, 1/10, 0], [0, 0, 1/10]] 

mean_2 = [0, 5, 0]
cov_2 = [[1/2, 0, 0], [0, 1/2, 0], [0, 0, 1/2]] 

mean_3 = [0, 0, 15]
cov_3 = [[1, 0, 0], [0, 1, 0], [0, 0, 1]]

# %%
cluster_3d_1 = np.random.multivariate_normal(mean_1, cov_1, 100)
x_3d_1 = cluster_3d_1[:,0]
y_3d_1 = cluster_3d_1[:,1]
z_3d_1 = cluster_3d_1[:,2]

# %%
cluster_3d_2 = np.random.multivariate_normal(mean_2, cov_2, 100)
x_3d_2 = cluster_3d_2[:,0]
y_3d_2 = cluster_3d_2[:,1]
z_3d_2 = cluster_3d_2[:,2]

# %%
cluster_3d_3 = np.random.multivariate_normal(mean_3, cov_3, 100)
x_3d_3 = cluster_3d_3[:,0]
y_3d_3 = cluster_3d_3[:,1]
z_3d_3 = cluster_3d_3[:,2]

# %%
fig = plt.figure(figsize=(7,7))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs = x_3d_1, ys = y_3d_1, zs = z_3d_1) # plot the point (2,3,4) on the figure
ax.scatter(xs = x_3d_2, ys = y_3d_2, zs = z_3d_2)
ax.scatter(xs = x_3d_3, ys = y_3d_3, zs = z_3d_3)

plt.show()

# %% [markdown]
# ### Choose $\epsilon = 0.1, k=2$

# %%
k = 2

# %%
A_transform = 1 / (math.sqrt(k)) * np.random.normal(0, 1, size=(2, 3))

# %%
A_transform
# Out:
# array([[ 0.3982443 ,  0.29703414,  0.48299535],
#        [-0.33885439, -0.33985223,  0.22321133]])

# %%
cluster_2d_1 = (A_transform @ cluster_3d_1.T)
cluster_2d_2 = (A_transform @ cluster_3d_2.T)
cluster_2d_3 = (A_transform @ cluster_3d_3.T)

# %%
(A_transform @ cluster_3d_1.T)[0,:]
# Out:
# array([1.9678194 , 1.64624757, 2.18560205, 2.18852387, 1.69632541,
#        1.90776669, 2.17822075, 1.86030181, 2.25078554, 1.99253575,
#        2.46344015, 2.01691932, 1.90479857, 1.74290381, 1.93237252,
#        2.01215436, 1.73379736, 2.01354903, 2.20142804, 1.87942538,
#        2.01649333, 2.12765685, 2.08439386, 2.24512002, 1.92680988,
#        1.93308982, 1.63656946, 2.0802828 , 2.17920451, 1.94894575,
#        1.69721937, 1.89819987, 2.32825487, 1.50541296, 2.03902108,
#        1.95974196, 1.83329006, 1.87502068, 1.91393681, 2.1494745 ,
#        1.80354244, 1.71371909, 2.12434559, 2.43368   , 1.86706669,
#        1.62940479, 2.04865929, 1.99467658, 1.93315326, 1.81357015,
#        1.70406754, 1.6931074 , 1.7094435 , 1.76036054, 2.29531187,
#        2.17481411, 1.66630771, 2.10806151, 2.12759339, 2.42973515,
#        1.95955032, 2.21334655, 2.07632363, 2.03196173, 1.94800028,
#        1.82624949, 1.9668703 , 1.88339328, 1.82390273, 1.7041739 ,
#        2.08686642, 2.22704315, 1.92208404, 2.01842392, 2.16797718,
#        1.88233409, 1.97686226, 2.04446827, 2.00606927, 1.93199746,
#        1.61765451, 2.32818514, 1.59035814, 2.50558623, 2.08879816,
#        2.29607994, 1.80261327, 1.98176735, 1.66965224, 2.17495317,
#        1.70637106, 1.7469298 , 2.1063326 , 2.09025397, 1.92490681,
#        2.12600365, 1.6903357 , 2.35323156, 2.09712384, 1.76054806])

# %%
x_2d_1 = cluster_2d_1[0,:]
y_2d_1 = cluster_2d_1[1,:]
x_2d_2 = cluster_2d_2[0,:]
y_2d_2 = cluster_2d_2[1,:]
x_2d_3 = cluster_2d_3[0,:]
y_2d_3 = cluster_2d_3[1,:]

x_2d_1
# Out:
# array([1.9678194 , 1.64624757, 2.18560205, 2.18852387, 1.69632541,
#        1.90776669, 2.17822075, 1.86030181, 2.25078554, 1.99253575,
#        2.46344015, 2.01691932, 1.90479857, 1.74290381, 1.93237252,
#        2.01215436, 1.73379736, 2.01354903, 2.20142804, 1.87942538,
#        2.01649333, 2.12765685, 2.08439386, 2.24512002, 1.92680988,
#        1.93308982, 1.63656946, 2.0802828 , 2.17920451, 1.94894575,
#        1.69721937, 1.89819987, 2.32825487, 1.50541296, 2.03902108,
#        1.95974196, 1.83329006, 1.87502068, 1.91393681, 2.1494745 ,
#        1.80354244, 1.71371909, 2.12434559, 2.43368   , 1.86706669,
#        1.62940479, 2.04865929, 1.99467658, 1.93315326, 1.81357015,
#        1.70406754, 1.6931074 , 1.7094435 , 1.76036054, 2.29531187,
#        2.17481411, 1.66630771, 2.10806151, 2.12759339, 2.42973515,
#        1.95955032, 2.21334655, 2.07632363, 2.03196173, 1.94800028,
#        1.82624949, 1.9668703 , 1.88339328, 1.82390273, 1.7041739 ,
#        2.08686642, 2.22704315, 1.92208404, 2.01842392, 2.16797718,
#        1.88233409, 1.97686226, 2.04446827, 2.00606927, 1.93199746,
#        1.61765451, 2.32818514, 1.59035814, 2.50558623, 2.08879816,
#        2.29607994, 1.80261327, 1.98176735, 1.66965224, 2.17495317,
#        1.70637106, 1.7469298 , 2.1063326 , 2.09025397, 1.92490681,
#        2.12600365, 1.6903357 , 2.35323156, 2.09712384, 1.76054806])

# %%
plt.scatter(x_2d_1, y_2d_1)
plt.scatter(x_2d_2, y_2d_2)
plt.scatter(x_2d_3, y_2d_3)

plt.show()
